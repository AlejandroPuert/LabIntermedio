# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import csv

# %% [markdown]
# ## Caracterización

# %%
can1 = []
can2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/canal1.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        can1.append(float(lines['Voltaje']))
        t1.append(float(lines['Tiempo']))
        
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/canal2.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        can2.append(float(lines['Voltaje']))
        t2.append(float(lines['Tiempo']))

# %%
plt.scatter(can1,t2,s=1)

# %% [markdown]
# ## R = 0

# %%
cap1 = []
cap2 = []
t = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia0/capacitancia_100nF_0resistencia.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje']))
        t.append(float(lines['Tiempo']))
        
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia0/capacitancia_10nF_0resistencia.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap2.append(float(lines['Voltaje']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 200

# %%
cap1 = []
cap2 = []
t = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia200/capacitancia_100nF_resistencia200.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje']))
        t.append(float(lines['Tiempo']))
        
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia200/capacitancia_10nF_resistencia200.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap2.append(float(lines['Voltaje']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 400

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia400/datos_400resistencia.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 600

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia600/datos_resistencia600.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 800

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia800/datos_resistencia800.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 1000

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia1000/datos_resistencia1000.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 1200

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia1200/datos_resistencia1200.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 1400

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia1400/datos_resistencia1400.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 1600

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia1600pm1/datos_1600.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=2)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 1800

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia1800pm1/datos_1800.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()

# %% [markdown]
# ## R = 2000

# %%
cap1 = []
cap2 = []
t1 = []
t2 = []
with open("/home/alejandro/Documents/Octavo/Intermedio/LabIntermedio/CHUA/Resistencia2000/datos_resistencia2000.csv", "r") as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    for lines in csv_reader:
        cap1.append(float(lines['Voltaje1']))
        t1.append(float(lines['Tiempo1']))
        cap2.append(float(lines['Voltaje2']))
        t2.append(float(lines['Tiempo2']))

# %%
plt.scatter(cap1,cap2,s=1)
plt.grid()
plt.xlabel('Voltaje C = 100nF')
plt.ylabel('Voltaje C = 10nF')
# Out:
# Text(0, 0.5, 'Voltaje C = 10nF')

# %%
plt.plot(t1,cap1)
plt.plot(t2,cap2)
plt.grid()
